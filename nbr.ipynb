# %%
import requests
import pandas as pd
import json

# Locale module
from nxr_classes import Organisations

# %%
##### Nasjonalt barnehageregister: Alle organisasjoner
NBR består av 14 924 organisasjoner. Vi skal hente ut detaljert informasjon om samtlige av dem.

# %%
nbr_organisations = Organisations('nbr')

nbr_organisations.get_overview()

nbr_organisations.overview.sample(10)
# Out:
#            Orgnr                                 Navn Karakteristikk Fylkesnr
# 11650  964948232                        Åsnes kommune           None       34  \
# 11640  964950679                        Løten kommune           None       34
# 13619  919597607               Sømådalen barnehage Da           None       34
# 2550   991366350               Bisjord Eiendom Bhg AS           None       03
# 13585  920108350           Filadelfia Kristiansand AS           None       10
# 14040  914325153             Engelsviken barnehage AS           None       30
# 12012  941139787                    Austevoll kommune           None       46
# 5588   983713246                         Berit Hansen           None       19
# 12048  939984194                       Alvdal kommune           None       34
# 2986   990446458  Espira Sandtoppen naturbarnehage AS           None       11
#
#       Kommunenr                            Epost  ErAktiv  ErBarnehage
# 11650      3418            post@asnes.kommune.no     True        False  \
# 11640      3412            post@loten.kommune.no     True        False
# 13619      3425                             None     True         True
# 2550       0301                dl.bisjord@bhg.no     True        False
# 13585      1001                             None    False        False
# 14040      3004                             None     True        False
# 12012      4625  postmottak@austevoll.kommune.no     True        False
# 5588       1902                                     False        False
# 12048      3428     postmottak@alvdal.kommune.no     True        False
# 2986       1149                   post@espira.no     True        False
#
#        ErBarnehageeier  ErOffentligBarnehage  ErPrivatBarnehage
# 11650             True                 False              False  \
# 11640             True                 False              False
# 13619            False                 False               True
# 2550             False                 False              False
# 13585            False                 False              False
# 14040             True                 False              False
# 12012             True                 False              False
# 5588             False                 False              False
# 12048             True                 False              False
# 2986              True                 False              False
#
#        ErInaktivIBasil                     DatoEndret
# 11650            False  2023-04-13T07:40:22.503+02:00
# 11640            False  2023-04-13T07:40:10.423+02:00
# 13619            False  2023-04-12T08:18:45.673+02:00
# 2550             False  2023-01-23T01:24:04.283+01:00
# 13585             True   2020-05-11T07:01:01.87+02:00
# 14040            False    2023-03-16T01:22:08.4+01:00
# 12012            False   2023-03-16T01:17:17.41+01:00
# 5588             False  2022-08-30T07:39:02.247+02:00
# 12048            False  2023-04-13T07:40:48.777+02:00
# 2986             False  2023-04-13T07:44:23.987+02:00

# %%
for org in nbr_organisations.overview['Orgnr']:
    nbr_organisations.get_org(org)
    nbr_organisations.flatten_json(org)


nbr_organisations.gen_df()

cols = nbr_organisations.df.columns.tolist()
first_cols = list()
end_cols = list()

for col in cols:
    if "Barnehagekategorier" in col or  "Naeringskoder" in col:
        end_cols.append(col)
    else:
        first_cols.append(col)

new_cols = first_cols + end_cols

nbr_organisations.df = nbr_organisations.df[new_cols]

# %%
nbr_organisations.df.to_excel(nbr_organisations.register +" - alle organisasjoner.xlsx")
